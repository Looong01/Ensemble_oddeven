# %%
import numpy as np

# %%
roc_score = np.load("../model/mean_roc_m1.npy")

# %%
print(roc_score)
# Out:
# [0.45412963 0.48016698 0.50242613 0.53462192 0.53932468 0.56201585
#  0.57603038 0.5869265  0.59999057 0.61196468 0.62180996 0.62877035
#  0.63710717 0.64357122 0.64931397 0.65032552 0.66007987 0.66600647
#  0.67027341 0.67611414 0.68108042 0.66902157 0.67959842 0.67893906
#  0.69090416 0.68399684 0.69500008 0.69437591 0.68360579 0.64802172
#  0.64493385 0.63637912 0.65241494 0.65872907 0.68592648 0.64466667
#  0.68961572 0.6002859  0.59347092 0.62662027 0.60961499 0.57605037
#  0.57659824 0.55426434 0.58471546 0.53350282 0.54878116 0.55721483
#  0.55733336 0.55985112 0.496006   0.53650173 0.41173058 0.50501864
#  0.51620051 0.54383347 0.47784586 0.53245016 0.53557463 0.52502228
#  0.59588931 0.50034671 0.50561254 0.48432103 0.50762918 0.53441161
#  0.49480582 0.52699626 0.5542559  0.474314   0.50644955 0.4940544
#  0.47641341 0.55356163 0.52761282 0.43606211 0.51386659 0.4766651
#  0.45764121 0.53918786 0.48040952 0.49360282 0.51282266 0.52010527
# ...

# %%
np.max(roc_score)
# Out:
# 0.695000077422152

# %%
import torch

# %%
result = torch.sigmoid(torch.tensor(0.5))

# %%
result.item() <0.5
# Out:
# False
